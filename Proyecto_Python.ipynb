# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ordenes = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_orders_dataset.csv")
clientes = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_customers_dataset.csv")
vendedores = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_sellers_dataset.csv")
productos = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_products_dataset.csv")
items = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_order_items_dataset.csv")
nombre_categoria = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_category_name_translation.csv")
localizacion = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_geolocation_dataset.csv")
pagos = pd.read_csv("/content/drive/MyDrive/Bootcamp/M3 - Python/Shopify/shopify_order_payments_dataset 2.csv")

# %%
ordenes
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
ordenes["customer_id"].nunique()
# Out:
# 99441

# %%
ordenes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
vendedores
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
productos
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
clientes
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
clientes["customer_id"].nunique()
# Out:
# 99441

# %%
clientes["customer_unique_id"].value_counts()
# Out:
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# ca77025e7201e3b30c44b472ff346268     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 6469f99c1f9dfae7733b25662e7f1782     7
#                                     ..
# 4f83c83b7ff5b544a8c75dcb8ad66e2e     1
# 3fe413dde400746c53c5d0d38b266ca2     1
# 289e1d1ce11a14bb169775d58ad2f1c2     1
# ec83d060d9a0abba4b409c544c744c2f     1
# 211e4234ffca5cec9b0ab183a1009256     1
# Name: count, Length: 96096, dtype: int64

# %%
clientes[clientes["customer_unique_id"]=="8d50f5eadf50201ccdcedfb9e2ac8455"]
# Out:
#                             customer_id                customer_unique_id  \
# 14186  1bd3585471932167ab72a84955ebefea  8d50f5eadf50201ccdcedfb9e2ac8455
# 15321  a8fabc805e9a10a3c93ae5bff642b86b  8d50f5eadf50201ccdcedfb9e2ac8455
# 16654  897b7f72042714efaa64ac306ba0cafc  8d50f5eadf50201ccdcedfb9e2ac8455
# 36122  b2b13de0770e06de50080fea77c459e6  8d50f5eadf50201ccdcedfb9e2ac8455
# 38073  42dbc1ad9d560637c9c4c1533746f86d  8d50f5eadf50201ccdcedfb9e2ac8455
# 40141  dfb941d6f7b02f57a44c3b7c3fefb44b  8d50f5eadf50201ccdcedfb9e2ac8455
# 48614  65f9db9dd07a4e79b625effa4c868fcb  8d50f5eadf50201ccdcedfb9e2ac8455
# 52574  1c62b48fb34ee043310dcb233caabd2e  8d50f5eadf50201ccdcedfb9e2ac8455
# 58707  a682769c4bc10fc6ef2101337a6c83c9  8d50f5eadf50201ccdcedfb9e2ac8455
# 67996  6289b75219d757a56c0cce8d9e427900  8d50f5eadf50201ccdcedfb9e2ac8455
# 72745  3414a9c813e3ca02504b8be8b2deb27f  8d50f5eadf50201ccdcedfb9e2ac8455
# 74510  0e4fdc084a6b9329ed55d62dcd653ccf  8d50f5eadf50201ccdcedfb9e2ac8455
# ...

# %%
localizacion
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
nombre_categoria
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
items.groupby("product_id")["order_id"].count().sort_values(ascending=False)
# Out:
# product_id
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# ffd7628b0b0b98ebc549e8e4c54a59af      1
# ffd63ee42a5c8cc5a15a1c8e2aa50011      1
# 002959d7a0b0990fe2d69988affcbc80      1
# 002552c0663708129c0019cc97552d7d      1
# 0021a87d4997a48b6cef1665602be0f5      1
# Name: order_id, Length: 32951, dtype: int64

# %%
items["order_item_id"].value_counts()
# Out:
# order_item_id
# 1     98666
# 2      9803
# 3      2287
# 4       965
# 5       460
# 6       256
# 7        58
# 8        36
# 9        28
# 10       25
# 11       17
# 12       13
# 13        8
# 14        7
# 15        5
# 16        3
# 17        3
# 18        3
# 19        3
# 20        3
# 21        1
# Name: count, dtype: int64

# %%
pagos
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
pagos["order_id"].nunique()
# Out:
# 99440

# %%
pagos_acum = pagos.groupby("order_id")["payment_value"].sum().reset_index()
pagos_acum
# Out:
#                                order_id  payment_value
# 0      00010242fe8c5a6d1ba2dd792cb16214          72.19
# 1      00018f77f2f0320c557190d7a144bdd3         259.83
# 2      000229ec398224ef6ca0657da4fc703e         216.87
# 3      00024acbcdf0a6daa1e931b038114c75          25.78
# 4      00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                 ...            ...
# 99435  fffc94f6ce00a00581880bf54a75a037         343.40
# 99436  fffcd46ef2263f404302a634eb57f7eb         386.53
# 99437  fffce4705a9662cd70adb13d4a31832d         116.85
# 99438  fffe18544ffabc95dfada21779c9644f          64.71
# 99439  fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 2 columns]

# %%
pagos_acum["payment_value"].min()
# Out:
# 0.0

# %%
data = ordenes.merge(pagos_acum, on="order_id", how="left").merge(clientes, on="customer_id", how="left")
data
##ordenes_final= ordenes.merge(articulos_nuevo, on="order_id", how="left")
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
#  8   payment_value                  99440 non-null  float64
#  9   customer_unique_id             99441 non-null  object
#  10  customer_zip_code_prefix       99441 non-null  int64
#  11  customer_city                  99441 non-null  object
# ...

# %%
data["order_purchase_timestamp"] = pd.to_datetime(data["order_purchase_timestamp"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
#  8   payment_value                  99440 non-null  float64
#  9   customer_unique_id             99441 non-null  object
#  10  customer_zip_code_prefix       99441 non-null  int64
#  11  customer_city                  99441 non-null  object
# ...

# %%
data[data["payment_value"].isna()==True]
# Out:
#                                order_id                       customer_id  \
# 30710  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 30710    delivered      2016-09-15 12:16:38  2016-09-15 12:16:38
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 30710          2016-11-07 17:11:53           2016-11-09 07:47:38
#
#       order_estimated_delivery_date  payment_value  \
# 30710           2016-10-04 00:00:00            NaN
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 30710  830d5b7aaa3b6f1e9ad63703bec97d23                     14600
#
#               customer_city customer_state
# 30710  sao joaquim da barra             SP

# %%
data[data["payment_value"]==0]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 39919  4637ca194b6387e2d538dc89b124b0ee  a73c1f73f5772cf801434bf984b0b1a7
# 40235  c8c528189310eaa44a745b8d9d26908b  197a2a6a77da93f678ea0d379f21da0a
#
#       order_status order_purchase_timestamp order_approved_at  \
# 1130      canceled      2018-08-28 15:26:39               NaN
# 39919     canceled      2018-09-03 14:14:25               NaN
# 40235     canceled      2018-08-28 20:05:14               NaN
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 1130                           NaN                           NaN
# 39919                          NaN                           NaN
# 40235                          NaN                           NaN
#
#       order_estimated_delivery_date  payment_value  \
# 1130            2018-09-12 00:00:00            0.0
# ...

# %%
data["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
prueba = data[data["order_status"]=="unavailable"]
prueba
# Out:
#                                order_id                       customer_id  \
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 586    c272bcd21c287498b4883c7512019702  9582c5bbecc65eb568e2c1d839b5cba1
# 687    37553832a3a89c9b2db59701c357ca67  7607cd563696c27ede287e515812d528
# 737    d57e15fb07fd180f06ab3926b39edcd2  470b93b3f1cde85550fc74cd3a476c78
# 1160   2f634e2cebf8c0283e7ef0989f77d217  7353b0fb8e8d9675e3a704c60ca44ebe
# ...                                 ...                               ...
# 99147  6cf5c427fb11bc5fe8abefa86aa7ba0b  91ac14a1e50bc022eeecf0c2ba37006a
# 99233  1c7c8ab324927f5b6e52338bd110bef4  95b1767df51d6fa09402267d8de314df
# 99252  aaab15da689073f8f9aa978a390a69d1  df20748206e4b865b2f14a5eabbfcf34
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
prueba["order_delivered_carrier_date"].unique()
# Out:
# array([nan], dtype=object)

# %%
dataset = data[(data['order_status'] != 'canceled') & (data['order_status'] != 'unavailable')].dropna(subset=["payment_value"])
dataset
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
dataset['mes_anio'] = dataset['order_purchase_timestamp'].dt.strftime('%Y-%m')
dataset
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# prompt: calcular la semana ISO de una fecha

dataset["semana_iso"] = dataset["order_purchase_timestamp"].dt.isocalendar().week
dataset
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
dataset["anio_semana"] = dataset["order_purchase_timestamp"].dt.strftime("%Y-%W")
dataset
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
fecha_maxima = dataset["order_purchase_timestamp"].max()
fecha_maxima
# Out:
# Timestamp('2018-09-03 09:06:57')

# %%
dataset["Dif_dias"] = (fecha_maxima - dataset["order_purchase_timestamp"]).dt.days
dataset
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
dataset_recencia = dataset.groupby("customer_unique_id")["order_purchase_timestamp"].max().reset_index()
dataset_recencia
# Out:
#                      customer_unique_id order_purchase_timestamp
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42
# ...                                 ...                      ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36
# 94985  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56
# 94986  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16
# 94987  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41
# 94988  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45
#
# [94989 rows x 2 columns]

# %%
dataset_recencia["Dif_dias"] = (fecha_maxima - dataset_recencia["order_purchase_timestamp"]).dt.days
dataset_recencia
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27       115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27       118
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03       541
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41       325
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# ...                                 ...                      ...       ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
# 94985  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56       266
# 94986  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16       572
# 94987  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41       123
# 94988  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45       488
#
# [94989 rows x 3 columns]

# %%
dataset_recencia["Recencia"] = pd.qcut(dataset_recencia["Dif_dias"], q=3, labels=[3, 2, 1])
dataset_recencia
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27       115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27       118
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03       541
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41       325
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# ...                                 ...                      ...       ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
# 94985  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56       266
# 94986  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16       572
# 94987  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41       123
# 94988  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45       488
#
#       Recencia
# 0            3
# 1            3
# 2            1
# ...

# %%
dataset_recencia["Recencia"].value_counts()
# Out:
# Recencia
# 3    31821
# 1    31636
# 2    31532
# Name: count, dtype: int64

# %%
dataset["anio_semana"].value_counts()
# Out:
# anio_semana
# 2017-47    2973
# 2017-48    2077
# 2018-31    2030
# 2018-19    1971
# 2018-32    1961
#            ...
# 2017-01      46
# 2016-41      37
# 2016-35       1
# 2016-51       1
# 2018-36       1
# Name: count, Length: 92, dtype: int64

# %%
dataset["mes_anio"].value_counts()
# Out:
# mes_anio
# 2017-11    7423
# 2018-01    7187
# 2018-03    7168
# 2018-04    6919
# 2018-05    6833
# 2018-02    6625
# 2018-08    6421
# 2018-07    6233
# 2018-06    6145
# 2017-12    5620
# 2017-10    4547
# 2017-08    4272
# 2017-09    4227
# 2017-07    3946
# 2017-05    3640
# 2017-06    3205
# 2017-03    2617
# 2017-04    2377
# 2017-02    1718
# 2017-01     787
# 2016-10     293
# 2016-09       1
# 2016-12       1
# 2018-09       1
# Name: count, dtype: int64

# %%
dataset["order_purchase_timestamp"].min()
# Out:
# Timestamp('2016-09-04 21:15:19')

# %%
dataset_frecuencia = dataset.groupby("customer_unique_id")["order_id"].count().reset_index().rename(columns={"order_id":"cantidad_ordenes"})
dataset_frecuencia
# Out:
#                      customer_unique_id  cantidad_ordenes
# 0      0000366f3b9a7992bf8c76cfdf3221e2                 1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f                 1
# 2      0000f46a3911fa3c0805444483337064                 1
# 3      0000f6ccb0745a6a4b88665a16c9f078                 1
# 4      0004aac84e0df4da2b147fca70cf8255                 1
# ...                                 ...               ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684                 1
# 94985  fffea47cd6d3cc0a88bd621562a9d061                 1
# 94986  ffff371b4d645b6ecea244b27531430a                 1
# 94987  ffff5962728ec6157033ef9805bacc48                 1
# 94988  ffffd2657e2aad2907e67c3e9daecbeb                 1
#
# [94989 rows x 2 columns]

# %%
dataset_frecuencia["cantidad_ordenes"].value_counts()
# Out:
# cantidad_ordenes
# 1     92101
# 2      2652
# 3       188
# 4        29
# 5         9
# 6         5
# 7         3
# 9         1
# 16        1
# Name: count, dtype: int64

# %%
dataset_frecuencia[dataset_frecuencia["cantidad_ordenes"]==3]
# Out:
#                      customer_unique_id  cantidad_ordenes
# 1082   02e9109b7e0a985108b43e573b6afb23                 3
# 1522   041caba6a63ace5818387698ea85cdb2                 3
# 2465   06a52782a04f0086d16b9c22d0e29438                 3
# 2874   07b1b60bca2b6326fa2adb259ea4a55f                 3
# 3297   08c07c761592a71b85136aa4fe76a6f4                 3
# ...                                 ...               ...
# 92338  f8bc1d81f395f6239a2a5ab1b9edf1ab                 3
# 93657  fc719c11b4dce594f47e1f9aa739a3a2                 3
# 94063  fd8ccc89be43894d2553494c71a61fd8                 3
# 94363  fe59d5878cd80080edbd29b5a0a4e1cf                 3
# 94830  ff922bdd6bafcdf99cb90d7f39cea5b3                 3
#
# [188 rows x 2 columns]

# %%
dataset_frecuencia["frecuencia"] = dataset_frecuencia["cantidad_ordenes"].apply(
    lambda x:1 if x == 1 else (2 if x == 2 else 3))

# %%
dataset_frecuencia["frecuencia"].value_counts()
# Out:
# frecuencia
# 1    92101
# 2     2652
# 3      236
# Name: count, dtype: int64

# %%
dataset_frecuencia[dataset_frecuencia["frecuencia"]==3]
# Out:
#                      customer_unique_id  cantidad_ordenes  frecuencia
# 1082   02e9109b7e0a985108b43e573b6afb23                 3           3
# 1522   041caba6a63ace5818387698ea85cdb2                 3           3
# 2465   06a52782a04f0086d16b9c22d0e29438                 3           3
# 2874   07b1b60bca2b6326fa2adb259ea4a55f                 3           3
# 3095   083ca1aa470c280236380973a48f77c6                 4           3
# ...                                 ...               ...         ...
# 93657  fc719c11b4dce594f47e1f9aa739a3a2                 3           3
# 94063  fd8ccc89be43894d2553494c71a61fd8                 3           3
# 94363  fe59d5878cd80080edbd29b5a0a4e1cf                 3           3
# 94434  fe81bb32c243a86b2f86fbf053fe6140                 5           3
# 94830  ff922bdd6bafcdf99cb90d7f39cea5b3                 3           3
#
# [236 rows x 3 columns]

# %%
dataset
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
dataset["payment_value"].describe()
# Out:
# count    98206.000000
# mean       160.266552
# std        219.121818
# min          9.590000
# 25%         62.000000
# 50%        105.280000
# 75%        176.750000
# max      13664.080000
# Name: payment_value, dtype: float64

# %%
dataset_monto = dataset.groupby("customer_unique_id")["payment_value"].sum().reset_index()
dataset_monto
# Out:
#                      customer_unique_id  payment_value
# 0      0000366f3b9a7992bf8c76cfdf3221e2         141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f          27.19
# 2      0000f46a3911fa3c0805444483337064          86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078          43.62
# 4      0004aac84e0df4da2b147fca70cf8255         196.89
# ...                                 ...            ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684        2067.42
# 94985  fffea47cd6d3cc0a88bd621562a9d061          84.58
# 94986  ffff371b4d645b6ecea244b27531430a         112.46
# 94987  ffff5962728ec6157033ef9805bacc48         133.69
# 94988  ffffd2657e2aad2907e67c3e9daecbeb          71.56
#
# [94989 rows x 2 columns]

# %%
dataset_monto["monto"]= pd.qcut(dataset_monto["payment_value"], q=3, labels=[1,2,3])
dataset_monto
# Out:
#                      customer_unique_id  payment_value monto
# 0      0000366f3b9a7992bf8c76cfdf3221e2         141.90     2
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f          27.19     1
# 2      0000f46a3911fa3c0805444483337064          86.22     2
# 3      0000f6ccb0745a6a4b88665a16c9f078          43.62     1
# 4      0004aac84e0df4da2b147fca70cf8255         196.89     3
# ...                                 ...            ...   ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684        2067.42     3
# 94985  fffea47cd6d3cc0a88bd621562a9d061          84.58     2
# 94986  ffff371b4d645b6ecea244b27531430a         112.46     2
# 94987  ffff5962728ec6157033ef9805bacc48         133.69     2
# 94988  ffffd2657e2aad2907e67c3e9daecbeb          71.56     1
#
# [94989 rows x 3 columns]

# %%
dataset_monto["monto"].value_counts()
# Out:
# monto
# 1    31668
# 3    31663
# 2    31658
# Name: count, dtype: int64

# %%
dataset_monto2= dataset_monto[dataset_monto["monto"]==3]
dataset_monto2
# Out:
#                      customer_unique_id  payment_value monto
# 4      0004aac84e0df4da2b147fca70cf8255         196.89     3
# 5      0004bd2a26a76fe21f786e4fbd80607f         166.98     3
# 7      00053a61a98854899e70ed204dd4bafe         419.18     3
# 18     000de6019bb59f34c099a907c151d855         257.44     3
# 22     000fbf0473c10fc1ab6f8d2d286ce20c         362.38     3
# ...                                 ...            ...   ...
# 94976  fff5eb4918b2bf4b2da476788d42051c        2844.96     3
# 94978  fff7219c86179ca6441b8f37823ba3d3         265.80     3
# 94982  fffbf87b7a1a6fa8b03f081c5f51a201         167.32     3
# 94983  fffcc512b7dfecaffd80f13614af1d16         710.70     3
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684        2067.42     3
#
# [31663 rows x 3 columns]

# %%
dataset_monto2["rango2"] = pd.qcut(dataset_monto2["payment_value"], q=3)
dataset_monto2
# Out:
# /tmp/ipython-input-171343723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_monto2["rango2"] = pd.qcut(dataset_monto2["payment_value"], q=3)
#                      customer_unique_id  payment_value monto  \
# 4      0004aac84e0df4da2b147fca70cf8255         196.89     3
# 5      0004bd2a26a76fe21f786e4fbd80607f         166.98     3
# 7      00053a61a98854899e70ed204dd4bafe         419.18     3
# 18     000de6019bb59f34c099a907c151d855         257.44     3
# 22     000fbf0473c10fc1ab6f8d2d286ce20c         362.38     3
# ...                                 ...            ...   ...
# 94976  fff5eb4918b2bf4b2da476788d42051c        2844.96     3
# 94978  fff7219c86179ca6441b8f37823ba3d3         265.80     3
# ...

# %%
dataset_monto2["rango2"].value_counts()
# Out:
# rango2
# (300.58, 13664.08]    10555
# (152.109, 196.18]     10554
# (196.18, 300.58]      10554
# Name: count, dtype: int64

# %%
dataset_recencia
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27       115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27       118
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03       541
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41       325
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# ...                                 ...                      ...       ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
# 94985  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56       266
# 94986  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16       572
# 94987  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41       123
# 94988  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45       488
#
#       Recencia
# 0            3
# 1            3
# 2            1
# ...

# %%
dataset_frecuencia
# Out:
#                      customer_unique_id  cantidad_ordenes  frecuencia
# 0      0000366f3b9a7992bf8c76cfdf3221e2                 1           1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f                 1           1
# 2      0000f46a3911fa3c0805444483337064                 1           1
# 3      0000f6ccb0745a6a4b88665a16c9f078                 1           1
# 4      0004aac84e0df4da2b147fca70cf8255                 1           1
# ...                                 ...               ...         ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684                 1           1
# 94985  fffea47cd6d3cc0a88bd621562a9d061                 1           1
# 94986  ffff371b4d645b6ecea244b27531430a                 1           1
# 94987  ffff5962728ec6157033ef9805bacc48                 1           1
# 94988  ffffd2657e2aad2907e67c3e9daecbeb                 1           1
#
# [94989 rows x 3 columns]

# %%
dataset_monto
# Out:
#                      customer_unique_id  payment_value monto
# 0      0000366f3b9a7992bf8c76cfdf3221e2         141.90     2
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f          27.19     1
# 2      0000f46a3911fa3c0805444483337064          86.22     2
# 3      0000f6ccb0745a6a4b88665a16c9f078          43.62     1
# 4      0004aac84e0df4da2b147fca70cf8255         196.89     3
# ...                                 ...            ...   ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684        2067.42     3
# 94985  fffea47cd6d3cc0a88bd621562a9d061          84.58     2
# 94986  ffff371b4d645b6ecea244b27531430a         112.46     2
# 94987  ffff5962728ec6157033ef9805bacc48         133.69     2
# 94988  ffffd2657e2aad2907e67c3e9daecbeb          71.56     1
#
# [94989 rows x 3 columns]

# %%
dataset_final = dataset_recencia.merge(dataset_frecuencia, on="customer_unique_id", how="left").merge(dataset_monto, on="customer_unique_id", how="left")
dataset_final
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27       115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27       118
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03       541
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41       325
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# ...                                 ...                      ...       ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
# 94985  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56       266
# 94986  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16       572
# 94987  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41       123
# 94988  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45       488
#
#       Recencia  cantidad_ordenes  frecuencia  payment_value monto
# ...

# %%
dataset_final["RFM"] = dataset_final["Recencia"].astype(str) + dataset_final["frecuencia"].astype(str) + dataset_final["monto"].astype(str)
dataset_final
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27       115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27       118
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03       541
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41       325
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# ...                                 ...                      ...       ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
# 94985  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56       266
# 94986  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16       572
# 94987  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41       123
# 94988  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45       488
#
# ...

# %%
dataset_final["RFM"].nunique()
# Out:
# 25

# %%
dataset_final["RFM"].value_counts(1)*100
# Out:
# RFM
# 211    11.262357
# 111    11.211825
# 312    11.022329
# 112    11.018118
# 311    10.745455
# 313    10.624388
# 212    10.580172
# 213    10.315931
# 113    10.179073
# 223     0.713767
# 323     0.713767
# 123     0.559012
# 322     0.235817
# 122     0.229500
# 222     0.224236
# 333     0.108434
# 233     0.062112
# 133     0.056849
# 321     0.044216
# 121     0.040005
# 221     0.031583
# 132     0.007369
# 332     0.005264
# 232     0.005264
# 131     0.003158
# Name: proportion, dtype: float64

# %%
dataset_final["RFM"].value_counts().plot(kind='bar', figsize=(12,6), color='skyblue')
plt.xlabel('RFM')
plt.ylabel('Frecuencia')
plt.title('Histograma de combinaciones RFM')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
dataset_final["RFM"].nunique()
# Out:
# 25

# %%
clientes
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
clientes["customer_unique_id"].nunique()
# Out:
# 96096

# %%
## eliminar duplicados de clientes en base a customer_unique_id
clientes_unicos = clientes.drop_duplicates(subset=["customer_unique_id"])
clientes_unicos
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
##unir dataset_final con clientes_unicos
dataset_final_city = dataset_final.merge(clientes_unicos, on="customer_unique_id", how="left")
dataset_final_city
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27       115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27       118
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03       541
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41       325
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# ...                                 ...                      ...       ...
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
# 94985  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56       266
# 94986  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16       572
# 94987  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41       123
# 94988  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45       488
#
# ...

# %%
data113 = dataset_final_city[dataset_final_city["RFM"]=="113"]
data113
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 18     000de6019bb59f34c099a907c151d855      2017-08-17 19:10:33       381
# 23     0010a452c6d13139e50b57f19f52e04e      2017-07-11 11:22:43       418
# 25     001147e649a7b1afd577e873841632dd      2017-08-31 17:12:56       367
# 27     0011805441c0d1b68b48002f1d005526      2017-04-24 13:36:48       496
# 28     0011857aff0e5871ce5eb429f21cdaf5      2017-06-28 11:08:38       431
# ...                                 ...                      ...       ...
# 94945  ffe39c116d96cd81dcdfd9dcca655cd1      2017-07-24 11:18:16       405
# 94946  ffe3e199b9d0b7fb7d2d29a5b9498447      2017-03-15 17:16:36       536
# 94955  ffe9102bb78a76921ba0ff3c4659616a      2017-06-09 13:25:52       450
# 94961  ffebb6424578e7bb153322da9d65634f      2017-01-16 14:04:11       594
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
#
# ...

# %%
data213 = dataset_final_city[dataset_final_city["RFM"]=="213"]
data213
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# 7      00053a61a98854899e70ed204dd4bafe      2018-02-28 11:15:41       186
# 55     0028a7d8db7b0247652509358ad8d755      2017-12-13 15:49:39       263
# 59     002aba8c1af80acacef6e011f9f23262      2018-02-27 12:47:48       187
# 84     00370dfde3d012c420d29657afc2fc8b      2018-01-29 12:54:38       216
# ...                                 ...                      ...       ...
# 94958  ffe9be10b9a58c5464d833e8b1b2c632      2017-11-27 14:18:56       279
# 94959  ffe9e41fbd14db4a7361347c56af5447      2018-02-11 12:51:07       203
# 94971  fff1bdd5c5e37ca79dd74deeb91aa5b6      2018-02-24 17:38:14       190
# 94978  fff7219c86179ca6441b8f37823ba3d3      2017-12-27 18:57:38       249
# 94982  fffbf87b7a1a6fa8b03f081c5f51a201      2017-12-27 22:36:41       249
#
# ...

# %%
data313 = dataset_final_city[dataset_final_city["RFM"]=="313"]
data313
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 5      0004bd2a26a76fe21f786e4fbd80607f      2018-04-05 19:33:16       150
# 22     000fbf0473c10fc1ab6f8d2d286ce20c      2018-07-26 09:43:52        38
# 36     001928b561575b2821c92254a2327d06      2018-08-24 21:17:00         9
# 40     0019e8c501c85848ac0966d45226fa1d      2018-05-01 09:25:32       124
# 42     001a34eb30ecb8e3aacb07c475ca4dd1      2018-07-11 19:49:54        53
# ...                                 ...                      ...       ...
# 94957  ffe96c782a5bc522bd8bad3bc638981a      2018-07-30 14:17:23        34
# 94965  ffeddf8aa7cdecf403e77b2e9a99e2ea      2018-05-13 16:04:51       112
# 94973  fff2ae16b99c6f3c785f0e052f2a9cfb      2018-04-20 11:03:47       135
# 94976  fff5eb4918b2bf4b2da476788d42051c      2018-07-02 16:39:59        62
# 94983  fffcc512b7dfecaffd80f13614af1d16      2018-04-11 00:34:32       145
#
# ...

# %%
data113["monto_categoria"]= pd.qcut(data113["payment_value"], q=3, labels=["bajo", "medio", "alto"])
data113
# Out:
# /tmp/ipython-input-3049724024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data113["monto_categoria"]= pd.qcut(data113["payment_value"], q=3, labels=["bajo", "medio", "alto"])
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 18     000de6019bb59f34c099a907c151d855      2017-08-17 19:10:33       381
# 23     0010a452c6d13139e50b57f19f52e04e      2017-07-11 11:22:43       418
# 25     001147e649a7b1afd577e873841632dd      2017-08-31 17:12:56       367
# 27     0011805441c0d1b68b48002f1d005526      2017-04-24 13:36:48       496
# 28     0011857aff0e5871ce5eb429f21cdaf5      2017-06-28 11:08:38       431
# ...                                 ...                      ...       ...
# ...

# %%
pd.crosstab(["customer_state"], data113["monto_categoria"], normalize="index")
# Out:
# monto_categoria      bajo     medio     alto
# row_0
# customer_state   0.333333  0.333437  0.33323

# %%
pd.crosstab(data113["customer_state"], data113["monto_categoria"], normalize=True)
# Out:
# monto_categoria      bajo     medio      alto
# customer_state
# AC               0.000207  0.000621  0.000931
# AL               0.001138  0.002792  0.003310
# AM               0.000827  0.000724  0.000621
# AP               0.000103  0.000310  0.000517
# BA               0.011894  0.015307  0.014996
# CE               0.005481  0.006309  0.009515
# DF               0.007136  0.006309  0.005481
# ES               0.008377  0.008584  0.005895
# GO               0.007653  0.007964  0.009101
# MA               0.003723  0.004034  0.004447
# MG               0.041680  0.037439  0.037232
# MS               0.003206  0.002379  0.002792
# MT               0.002999  0.003620  0.005378
# PA               0.005068  0.006205  0.007033
# PB               0.002379  0.002896  0.004447
# PE               0.007446  0.006723  0.006619
# PI               0.003516  0.002172  0.002792
# PR               0.017479  0.014479  0.016858
# RJ               0.049747  0.045093  0.048402
# ...

# %%
dataset_filtro = dataset_final_city[(dataset_final_city["RFM"]=="313") | (dataset_final_city["RFM"]=="213") | (dataset_final_city["RFM"]=="113")]
dataset_filtro
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42       292
# 5      0004bd2a26a76fe21f786e4fbd80607f      2018-04-05 19:33:16       150
# 7      00053a61a98854899e70ed204dd4bafe      2018-02-28 11:15:41       186
# 18     000de6019bb59f34c099a907c151d855      2017-08-17 19:10:33       381
# 22     000fbf0473c10fc1ab6f8d2d286ce20c      2018-07-26 09:43:52        38
# ...                                 ...                      ...       ...
# 94976  fff5eb4918b2bf4b2da476788d42051c      2018-07-02 16:39:59        62
# 94978  fff7219c86179ca6441b8f37823ba3d3      2017-12-27 18:57:38       249
# 94982  fffbf87b7a1a6fa8b03f081c5f51a201      2017-12-27 22:36:41       249
# 94983  fffcc512b7dfecaffd80f13614af1d16      2018-04-11 00:34:32       145
# 94984  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36       451
#
# ...

# %%
pd.crosstab(dataset_filtro["customer_state"], dataset_filtro["RFM"], normalize="index")*100
# Out:
# RFM                   113        213        313
# customer_state
# AC              47.222222  19.444444  33.333333
# AL              39.106145  33.519553  27.374302
# AM              37.500000  32.142857  30.357143
# AP              30.000000  46.666667  23.333333
# BA              35.111876  30.464716  34.423408
# CE              38.077634  31.792976  30.129390
# DF              27.853881  36.529680  35.616438
# ES              34.370140  33.125972  32.503888
# GO              36.825886  30.046225  33.127889
# MA              38.436482  33.550489  28.013029
# MG              31.996587  35.494881  32.508532
# MS              32.530120  34.538153  32.931727
# MT              33.720930  35.174419  31.104651
# PA              40.596330  28.669725  30.733945
# PB              36.015326  28.352490  35.632184
# PE              30.408472  32.375189  37.216339
# PI              35.652174  28.260870  36.086957
# PR              32.306639  32.238193  35.455168
# ...

# %%
data313["customer_state"].value_counts(1)*100
# Out:
# customer_state
# SP    38.921918
# RJ    12.356322
# MG    11.325803
# RS     5.142687
# PR     5.132778
# BA     3.963535
# SC     3.913991
# PE     2.437574
# DF     2.318668
# GO     2.130400
# ES     2.070947
# CE     1.615141
# PA     1.327784
# MT     1.060246
# PB     0.921522
# MA     0.852160
# PI     0.822434
# MS     0.812525
# RN     0.713436
# AL     0.485533
# SE     0.455807
# RO     0.386445
# TO     0.386445
# AM     0.168450
# AC     0.118906
# RR     0.089180
# AP     0.069362
# Name: proportion, dtype: float64

# %%
(data313["customer_state"].value_counts(1)*100).plot(kind='bar', figsize=(12,6), color='skyblue')
plt.xlabel('customer_state')
plt.ylabel('% de participación')
plt.title('% Participación de estados')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data313
# Out:
#                      customer_unique_id order_purchase_timestamp  Dif_dias  \
# 5      0004bd2a26a76fe21f786e4fbd80607f      2018-04-05 19:33:16       150
# 22     000fbf0473c10fc1ab6f8d2d286ce20c      2018-07-26 09:43:52        38
# 36     001928b561575b2821c92254a2327d06      2018-08-24 21:17:00         9
# 40     0019e8c501c85848ac0966d45226fa1d      2018-05-01 09:25:32       124
# 42     001a34eb30ecb8e3aacb07c475ca4dd1      2018-07-11 19:49:54        53
# ...                                 ...                      ...       ...
# 94957  ffe96c782a5bc522bd8bad3bc638981a      2018-07-30 14:17:23        34
# 94965  ffeddf8aa7cdecf403e77b2e9a99e2ea      2018-05-13 16:04:51       112
# 94973  fff2ae16b99c6f3c785f0e052f2a9cfb      2018-04-20 11:03:47       135
# 94976  fff5eb4918b2bf4b2da476788d42051c      2018-07-02 16:39:59        62
# 94983  fffcc512b7dfecaffd80f13614af1d16      2018-04-11 00:34:32       145
#
# ...

# %%
data313_ordenes = data313.merge(ordenes, on="customer_id", how="inner")
data313_ordenes
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 0      0004bd2a26a76fe21f786e4fbd80607f        2018-04-05 19:33:16       150
# 1      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 2      001928b561575b2821c92254a2327d06        2018-08-24 21:17:00         9
# 3      0019e8c501c85848ac0966d45226fa1d        2018-05-01 09:25:32       124
# 4      001a34eb30ecb8e3aacb07c475ca4dd1        2018-07-11 19:49:54        53
# ...                                 ...                        ...       ...
# 10087  ffe96c782a5bc522bd8bad3bc638981a        2018-07-30 14:17:23        34
# 10088  ffeddf8aa7cdecf403e77b2e9a99e2ea        2018-05-13 16:04:51       112
# 10089  fff2ae16b99c6f3c785f0e052f2a9cfb        2018-04-20 11:03:47       135
# 10090  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 10091  fffcc512b7dfecaffd80f13614af1d16        2018-04-11 00:34:32       145
#
# ...

# %%
data313_ordenes_items = data313_ordenes.merge(items, on="order_id", how="inner")
data313_ordenes_items
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 0      0004bd2a26a76fe21f786e4fbd80607f        2018-04-05 19:33:16       150
# 1      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 2      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 3      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 4      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# ...                                 ...                        ...       ...
# 12839  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12840  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12841  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12842  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12843  fffcc512b7dfecaffd80f13614af1d16        2018-04-11 00:34:32       145
#
# ...

# %%
data313_ordenes_items["customer_unique_id"].value_counts()
# Out:
# customer_unique_id
# 7582a5a77fc2976628f46a13ec91b375    13
# d3383e8df3cd44cd351aecff92e34627    12
# 37bc3d463e2a0024012a7fa587597a3c    12
# 4d99682572b7b5932340a0bce676c18c    12
# a5c6335399140e986db84120c425adf0    11
#                                     ..
# ffa00504cf231ac90f01bf4e86f9782d     1
# ff9d6196f8a9419142b5a70a0dbf469d     1
# ff9c030fb4209fbf442ae1368a6b376a     1
# ff9a8f06a79108c039694913b23e4393     1
# ff954519e2c82aa365ccf6f30fb0c259     1
# Name: count, Length: 10085, dtype: int64

# %%
data313_ordenes_items_productos = data313_ordenes_items.merge(productos, on="product_id", how="inner")
data313_ordenes_items_productos
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 0      0004bd2a26a76fe21f786e4fbd80607f        2018-04-05 19:33:16       150
# 1      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 2      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 3      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 4      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# ...                                 ...                        ...       ...
# 12839  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12840  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12841  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12842  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12843  fffcc512b7dfecaffd80f13614af1d16        2018-04-11 00:34:32       145
#
# ...

# %%
data313_ordenes_items_productos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_unique_id             12844 non-null  object
#  1   order_purchase_timestamp_x     12844 non-null  datetime64[ns]
#  2   Dif_dias                       12844 non-null  int64
#  3   Recencia                       12844 non-null  category
#  4   cantidad_ordenes               12844 non-null  int64
#  5   frecuencia                     12844 non-null  int64
#  6   payment_value                  12844 non-null  float64
#  7   monto                          12844 non-null  category
#  8   RFM                            12844 non-null  object
#  9   customer_id                    12844 non-null  object
#  10  customer_zip_code_prefix       12844 non-null  int64
#  11  customer_city                  12844 non-null  object
# ...

# %%
data313_ordenes_items_productos["order_id"]
# Out:
# 0        3e470077b690ea3e3d501cffb5e0c499
# 1        87440e08790d85796f5b8bc9f5ed2707
# 2        87440e08790d85796f5b8bc9f5ed2707
# 3        87440e08790d85796f5b8bc9f5ed2707
# 4        87440e08790d85796f5b8bc9f5ed2707
#                        ...
# 12839    cf4659487be50c0c317cff3564c4a840
# 12840    cf4659487be50c0c317cff3564c4a840
# 12841    cf4659487be50c0c317cff3564c4a840
# 12842    cf4659487be50c0c317cff3564c4a840
# 12843    158986977fa0c5043a8200b6b4563979
# Name: order_id, Length: 12844, dtype: object

# %% [markdown]
# ###Filtrando SP

# %%
data313_ordenes_items_productos_SP = data313_ordenes_items_productos[data313_ordenes_items_productos["customer_state"]=="SP"]
data313_ordenes_items_productos_SP
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 0      0004bd2a26a76fe21f786e4fbd80607f        2018-04-05 19:33:16       150
# 1      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 2      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 3      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 4      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# ...                                 ...                        ...       ...
# 12816  ff7f36f6ba0f1126bb95b635322cf9d2        2018-04-14 08:43:15       142
# 12818  ff8dead90fad99d74213aacf611a2849        2018-04-27 17:01:12       128
# 12821  ff946932c3126fc35f53628633d103b6        2018-08-01 00:02:17        33
# 12822  ff954519e2c82aa365ccf6f30fb0c259        2018-05-13 22:25:20       112
# 12823  ff9a8f06a79108c039694913b23e4393        2018-05-17 16:59:15       108
#
# ...

# %% [markdown]
# ###Filtrando diferentes a SP

# %%
data313_ordenes_items_productos_sin_SP = data313_ordenes_items_productos[data313_ordenes_items_productos["customer_state"]!="SP"]
data313_ordenes_items_productos_sin_SP
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 7      0019e8c501c85848ac0966d45226fa1d        2018-05-01 09:25:32       124
# 11     003162bf0351f47a1a247992b8b9b42d        2018-07-14 15:45:27        50
# 12     0033f4a2887e07e25aa1204d482f41ba        2018-06-26 01:07:23        69
# 13     00344274804f3b8003de1b0562ae01df        2018-07-09 14:09:25        55
# 16     003a5571a07dcf09bf117d13d2980ba3        2018-07-25 10:57:54        39
# ...                                 ...                        ...       ...
# 12839  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12840  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12841  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12842  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 12843  fffcc512b7dfecaffd80f13614af1d16        2018-04-11 00:34:32       145
#
# ...

# %% [markdown]
# #### Filtrando las estados principales excepto SP

# %%
data313_ordenes_items_productos_Gen =  data313_ordenes_items_productos_sin_SP[data313_ordenes_items_productos_sin_SP["customer_state"].isin(["RJ", "MG","RS", "PR", "BA", "SC"])]
data313_ordenes_items_productos_Gen
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 12     0033f4a2887e07e25aa1204d482f41ba        2018-06-26 01:07:23        69
# 16     003a5571a07dcf09bf117d13d2980ba3        2018-07-25 10:57:54        39
# 18     003ae409f37c3c30cb1c974af3a42692        2018-08-15 11:37:45        18
# 24     00504b68faa074d0f40adcb4f7727f71        2018-08-11 23:17:37        22
# 25     00504b68faa074d0f40adcb4f7727f71        2018-08-11 23:17:37        22
# ...                                 ...                        ...       ...
# 12831  ffc7d48d48327cf57757436b3f4706b0        2018-04-18 18:48:21       137
# 12832  ffcb3eb07f2a033d45949fcecd160d98        2018-05-12 18:13:33       113
# 12834  ffe96c782a5bc522bd8bad3bc638981a        2018-07-30 14:17:23        34
# 12836  fff2ae16b99c6f3c785f0e052f2a9cfb        2018-04-20 11:03:47       135
# 12843  fffcc512b7dfecaffd80f13614af1d16        2018-04-11 00:34:32       145
#
# ...

# %%
data313_ordenes_items_productos_SP.groupby("product_category_name")["payment_value"].sum().sort_values(ascending=False).head(15)
# Out:
# product_category_name
# beleza_saude                         180017.23
# cama_mesa_banho                      162559.60
# relogios_presentes                   143733.64
# utilidades_domesticas                122773.49
# moveis_decoracao                     118802.90
# informatica_acessorios               101333.95
# esporte_lazer                         88349.62
# construcao_ferramentas_construcao     61263.33
# automotivo                            56495.44
# moveis_escritorio                     54122.75
# bebes                                 53705.99
# ferramentas_jardim                    48888.66
# telefonia                             40560.46
# perfumaria                            38483.69
# cool_stuff                            38271.45
# Name: payment_value, dtype: float64

# %%
data313_ordenes_items_productos_SP["product_category_name"].value_counts().sort_values(ascending=False).head(15)
# Out:
# product_category_name
# cama_mesa_banho                      568
# beleza_saude                         544
# relogios_presentes                   437
# moveis_decoracao                     417
# utilidades_domesticas                387
# esporte_lazer                        309
# informatica_acessorios               306
# automotivo                           174
# bebes                                156
# moveis_escritorio                    155
# perfumaria                           153
# ferramentas_jardim                   136
# cool_stuff                           132
# pet_shop                             126
# construcao_ferramentas_construcao    122
# Name: count, dtype: int64

# %%
prueba2= data313_ordenes_items_productos_Gen.groupby(["customer_state", "product_category_name"])["payment_value"].sum().reset_index()
prueba2
# Out:
#     customer_state      product_category_name  payment_value
# 0               BA  agro_industria_e_comercio        2768.52
# 1               BA           artigos_de_natal         368.66
# 2               BA                      audio         611.81
# 3               BA                 automotivo       11904.73
# 4               BA                      bebes        6925.17
# ..             ...                        ...            ...
# 276             SC         relogios_presentes       10103.91
# 277             SC    sinalizacao_e_seguranca         670.64
# 278             SC                  telefonia        4498.44
# 279             SC             telefonia_fixa         579.36
# 280             SC      utilidades_domesticas       16218.57
#
# [281 rows x 3 columns]

# %%
top_categorias = (prueba2.sort_values(['customer_state', 'payment_value'], ascending=[True, False]).groupby('customer_state').head(5))

# %%
top_categorias
# Out:
#     customer_state   product_category_name  payment_value
# 6               BA            beleza_saude       21177.62
# 37              BA      relogios_presentes       19302.23
# 33              BA                     pcs       17220.06
# 8               BA         cama_mesa_banho       12431.05
# 3               BA              automotivo       11904.73
# 48              MG            beleza_saude       61628.05
# 93              MG   utilidades_domesticas       42848.33
# 50              MG         cama_mesa_banho       39157.44
# 89              MG      relogios_presentes       38467.90
# 66              MG           esporte_lazer       32806.15
# 134             PR      relogios_presentes       24229.34
# 127             PR       moveis_escritorio       20843.62
# 126             PR        moveis_decoracao       19618.53
# 100             PR            beleza_saude       19583.33
# 116             PR           esporte_lazer       15765.96
# ...

# %%
top_categorias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 6 to 267
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_state         30 non-null     object
#  1   product_category_name  30 non-null     object
#  2   payment_value          30 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 960.0+ bytes

# %%
top_categorias_menos = (prueba2.sort_values(['customer_state', 'payment_value'], ascending=[True, False]).groupby('customer_state').tail(5))
top_categorias_menos
# Out:
#     customer_state               product_category_name  payment_value
# 5               BA                             bebidas         321.37
# 9               BA                       casa_conforto         278.66
# 30              BA                       moveis_quarto         264.76
# 22              BA                    fashion_calcados         227.83
# 10              BA                     casa_construcao         218.48
# 70              MG       industria_comercio_e_negocios         225.35
# 76              MG                        market_place         218.98
# 62              MG                    eletrodomesticos         217.29
# 53              MG                           cine_foto         189.60
# 59              MG       construcao_ferramentas_jardim         166.55
# 117             PR         fashion_bolsas_e_acessorios         481.64
# 123             PR                     livros_tecnicos         479.20
# ...

# %%
prueba2_producto= data313_ordenes_items_productos_Gen.groupby(["customer_state", "product_id", "product_category_name"])["payment_value"].sum().reset_index()
prueba2_producto
# Out:
#      customer_state                        product_id  \
# 0                BA  01cb96c64e8e35f29826a58963f6ecc5
# 1                BA  01cf56cd6138b926a4802d16fc304149
# 2                BA  02ad78835ec3f72e750d1dfa6a7e11b3
# 3                BA  02b750ee6f6f12a23c311b775ee4427a
# 4                BA  03826ede2cac52b3011b58cfd58c84f9
# ...             ...                               ...
# 3634             SC  fdd06e4d9669d1f11992a3973a0fdd7b
# 3635             SC  fe077ec80df6b4ee60bb4498d5ab1962
# 3636             SC  fe705ffbaa3804c5562b8b1046157a6c
# 3637             SC  fe9dfbe7f974621789683b7b78be2a16
# 3638             SC  ff92ca9bb0b3f4ec00a9b76c9f68cb3a
#
#                   product_category_name  payment_value
# 0     construcao_ferramentas_iluminacao         163.06
# 1                           eletronicos         241.25
# 2                      moveis_decoracao         762.96
# 3                                 bebes         274.90
# ...

# %%
top_categorias_productos = (prueba2_producto.sort_values(['customer_state', 'payment_value'], ascending=[True, False]).groupby('customer_state').head(5))
top_categorias_productos
# Out:
#      customer_state                        product_id  \
# 41               BA  1f411e9a31196b71ed8438c8254b858e
# 191              BA  8ed094bfe076c568f6bb10feada3f75d
# 133              BA  5f00c50de3d989194f0439e343480372
# 97               BA  4180a49d4b879e727ad2c8e82a9f4d87
# 185              BA  86999f823d7791c5796d506ae0ed44ea
# 579              MG  3dd2a17168ec895c781a9191c1e95ad7
# 911              MG  97f1396a5a1f7c07ba51784efdec44b8
# 889              MG  928e52a9ad53a294fdcc91bcf59d1751
# 741              MG  6cdd53843498f92890544667809f1595
# 891              MG  933f4f76eae38d2a97ecfb7c6355f0bc
# 1580             PR  8ed094bfe076c568f6bb10feada3f75d
# 1636             PR  b114bf337c0626166abe574eee9e3f32
# 1622             PR  a9516a079e37a9c9c36b9b78b10169e8
# 1592             PR  993245facdeea0014e73a3e18750c123
# 1303             PR  0433830caca22b01a0f477d31307b043
# 1827             RJ  0c9439abe84dc40a64fc164365c4d064
# ...

# %%
data313_ordenes_items_productos_Gen
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 12     0033f4a2887e07e25aa1204d482f41ba        2018-06-26 01:07:23        69
# 16     003a5571a07dcf09bf117d13d2980ba3        2018-07-25 10:57:54        39
# 18     003ae409f37c3c30cb1c974af3a42692        2018-08-15 11:37:45        18
# 24     00504b68faa074d0f40adcb4f7727f71        2018-08-11 23:17:37        22
# 25     00504b68faa074d0f40adcb4f7727f71        2018-08-11 23:17:37        22
# ...                                 ...                        ...       ...
# 12831  ffc7d48d48327cf57757436b3f4706b0        2018-04-18 18:48:21       137
# 12832  ffcb3eb07f2a033d45949fcecd160d98        2018-05-12 18:13:33       113
# 12834  ffe96c782a5bc522bd8bad3bc638981a        2018-07-30 14:17:23        34
# 12836  fff2ae16b99c6f3c785f0e052f2a9cfb        2018-04-20 11:03:47       135
# 12843  fffcc512b7dfecaffd80f13614af1d16        2018-04-11 00:34:32       145
#
# ...

# %%
data313_ordenes_items_productos_Gen["Dia_Sem"] = data313_ordenes_items_productos_Gen["order_purchase_timestamp_x"].dt.day_name()
data313_ordenes_items_productos_Gen
# Out:
# /tmp/ipython-input-3004626741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data313_ordenes_items_productos_Gen["Dia_Sem"] = data313_ordenes_items_productos_Gen["order_purchase_timestamp_x"].dt.day_name()
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 12     0033f4a2887e07e25aa1204d482f41ba        2018-06-26 01:07:23        69
# 16     003a5571a07dcf09bf117d13d2980ba3        2018-07-25 10:57:54        39
# 18     003ae409f37c3c30cb1c974af3a42692        2018-08-15 11:37:45        18
# 24     00504b68faa074d0f40adcb4f7727f71        2018-08-11 23:17:37        22
# 25     00504b68faa074d0f40adcb4f7727f71        2018-08-11 23:17:37        22
# ...

# %%
data313_ordenes_items_productos_Gen.groupby(["customer_state","product_category_name", "Dia_Sem"])["Dia_Sem"].count()
# Out:
# customer_state  product_category_name      Dia_Sem
# BA              agro_industria_e_comercio  Thursday      2
#                                            Tuesday       1
#                 artigos_de_natal           Sunday        1
#                 audio                      Monday        1
#                 automotivo                 Friday        3
#                                                         ..
# SC              utilidades_domesticas      Saturday      2
#                                            Sunday        5
#                                            Thursday      4
#                                            Tuesday      11
#                                            Wednesday     6
# Name: Dia_Sem, Length: 1130, dtype: int64

# %%
data313_ordenes_items_productos_Gen.groupby(["customer_state", "Dia_Sem"])["Dia_Sem"].count()
# Out:
# customer_state  Dia_Sem
# BA              Friday        53
#                 Monday        71
#                 Saturday      49
#                 Sunday        58
#                 Thursday      81
#                 Tuesday       76
#                 Wednesday     75
# MG              Friday       199
#                 Monday       266
#                 Saturday     146
#                 Sunday       146
#                 Thursday     216
#                 Tuesday      229
#                 Wednesday    242
# PR              Friday        95
#                 Monday       141
#                 Saturday      57
#                 Sunday        74
#                 Thursday      95
#                 Tuesday       98
#                 Wednesday     97
# RJ              Friday       237
#                 Monday       246
#                 Saturday     186
#                 Sunday       185
#                 Thursday     222
#                 Tuesday      249
# ...

# %% [markdown]
# #### NUEVA FORMA

# %%
data313_ordenes
# Out:
#                      customer_unique_id order_purchase_timestamp_x  Dif_dias  \
# 0      0004bd2a26a76fe21f786e4fbd80607f        2018-04-05 19:33:16       150
# 1      000fbf0473c10fc1ab6f8d2d286ce20c        2018-07-26 09:43:52        38
# 2      001928b561575b2821c92254a2327d06        2018-08-24 21:17:00         9
# 3      0019e8c501c85848ac0966d45226fa1d        2018-05-01 09:25:32       124
# 4      001a34eb30ecb8e3aacb07c475ca4dd1        2018-07-11 19:49:54        53
# ...                                 ...                        ...       ...
# 10087  ffe96c782a5bc522bd8bad3bc638981a        2018-07-30 14:17:23        34
# 10088  ffeddf8aa7cdecf403e77b2e9a99e2ea        2018-05-13 16:04:51       112
# 10089  fff2ae16b99c6f3c785f0e052f2a9cfb        2018-04-20 11:03:47       135
# 10090  fff5eb4918b2bf4b2da476788d42051c        2018-07-02 16:39:59        62
# 10091  fffcc512b7dfecaffd80f13614af1d16        2018-04-11 00:34:32       145
#
# ...

# %% [markdown]
# ### esta tabla tiene product id unicos pero ordenes id pueden estar repetidas

# %%
items2 = items.merge(data313_ordenes, on="order_id", how="inner")
display(items2)
# Out:
#                                order_id  order_item_id  \
# 0      000576fe39319847cbb9d288c5617fa6              1
# 1      0009c9a17f916a706d71784483a5d643              1
# 2      000aed2e25dbad2f9ddb70584c5a2ded              1
# 3      00254baeb6c932b0a8aeead91fbd02b5              1
# 4      0025c5d1a8ca53a240ec2634bb4492ea              1
# ...                                 ...            ...
# 12839  ffc97f5975c4aa1b3c9754d83050c73d              1
# 12840  ffea20c7630343a6cd9e09858c1295cd              1
# 12841  ffebd80e3291e811c308365936897efd              1
# 12842  fffc94f6ce00a00581880bf54a75a037              1
# 12843  fffcd46ef2263f404302a634eb57f7eb              1
#
#                              product_id                         seller_id  \
# 0      557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 1      3f27ac8e699df3d300ec4a5d8c5cf0b2  fcb5ace8bcc92f75707dc0f01a27d269
# 2      4fa33915031a8cde03dd0d3e8fb27f01  fe2032dab1a61af8794248c8196565c9
# ...

# %%
items4 = items2.merge(productos, on="product_id", how="inner")
display(items4)
# Out:
#                                order_id  order_item_id  \
# 0      000576fe39319847cbb9d288c5617fa6              1
# 1      0009c9a17f916a706d71784483a5d643              1
# 2      000aed2e25dbad2f9ddb70584c5a2ded              1
# 3      00254baeb6c932b0a8aeead91fbd02b5              1
# 4      0025c5d1a8ca53a240ec2634bb4492ea              1
# ...                                 ...            ...
# 12839  ffc97f5975c4aa1b3c9754d83050c73d              1
# 12840  ffea20c7630343a6cd9e09858c1295cd              1
# 12841  ffebd80e3291e811c308365936897efd              1
# 12842  fffc94f6ce00a00581880bf54a75a037              1
# 12843  fffcd46ef2263f404302a634eb57f7eb              1
#
#                              product_id                         seller_id  \
# 0      557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 1      3f27ac8e699df3d300ec4a5d8c5cf0b2  fcb5ace8bcc92f75707dc0f01a27d269
# 2      4fa33915031a8cde03dd0d3e8fb27f01  fe2032dab1a61af8794248c8196565c9
# ...

# %%
items4["Dia_Sem"] = items4["order_purchase_timestamp_x"].dt.day_name()
items4
# Out:
#                                order_id  order_item_id  \
# 0      000576fe39319847cbb9d288c5617fa6              1
# 1      0009c9a17f916a706d71784483a5d643              1
# 2      000aed2e25dbad2f9ddb70584c5a2ded              1
# 3      00254baeb6c932b0a8aeead91fbd02b5              1
# 4      0025c5d1a8ca53a240ec2634bb4492ea              1
# ...                                 ...            ...
# 12839  ffc97f5975c4aa1b3c9754d83050c73d              1
# 12840  ffea20c7630343a6cd9e09858c1295cd              1
# 12841  ffebd80e3291e811c308365936897efd              1
# 12842  fffc94f6ce00a00581880bf54a75a037              1
# 12843  fffcd46ef2263f404302a634eb57f7eb              1
#
#                              product_id                         seller_id  \
# 0      557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 1      3f27ac8e699df3d300ec4a5d8c5cf0b2  fcb5ace8bcc92f75707dc0f01a27d269
# 2      4fa33915031a8cde03dd0d3e8fb27f01  fe2032dab1a61af8794248c8196565c9
# ...

# %%
items3 = items4[items4["customer_state"]=="SP"]
items3
# Out:
#                                order_id  order_item_id  \
# 0      000576fe39319847cbb9d288c5617fa6              1
# 1      0009c9a17f916a706d71784483a5d643              1
# 2      000aed2e25dbad2f9ddb70584c5a2ded              1
# 5      0029c5db35ef291ce99d1262012e7daa              1
# 6      002c9def9c9b951b1bec6d50753c9891              1
# ...                                 ...            ...
# 12824  ff632bc583a94f23c59db4cbaa0ba2ab              1
# 12825  ff632bc583a94f23c59db4cbaa0ba2ab              2
# 12828  ff9de84a5b397156b1f1f216fd5bf074              1
# 12829  ff9ec55d9d4d0d2c46cdb45f4c1b4910              1
# 12840  ffea20c7630343a6cd9e09858c1295cd              1
#
#                              product_id                         seller_id  \
# 0      557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 1      3f27ac8e699df3d300ec4a5d8c5cf0b2  fcb5ace8bcc92f75707dc0f01a27d269
# 2      4fa33915031a8cde03dd0d3e8fb27f01  fe2032dab1a61af8794248c8196565c9
# ...

# %%
prueba3= items3.groupby(["customer_state", "product_id"])["order_id"].count().sort_values(ascending=False).reset_index()
prueba3
# Out:
#      customer_state                        product_id  order_id
# 0                SP  6f3b5b605d91b7439c5e3f5a8dffeea7        33
# 1                SP  3dd2a17168ec895c781a9191c1e95ad7        33
# 2                SP  d285360f29ac7fd97640bf0baef03de0        32
# 3                SP  bb50f2e236e5eea0100680137654686c        31
# 4                SP  19c91ef95d509ea33eda93495c4d3481        30
# ...             ...                               ...       ...
# 2890             SP  fff1059cd247279f3726b7696c66e44e         1
# 2891             SP  0182db9fc95fd36e324e8a4c40c0819a         1
# 2892             SP  fe7df6d2f5226a4be89e7f2884c88e8c         1
# 2893             SP  fe8b0ea4a95d3a6488d8e23b41720e46         1
# 2894             SP  03826ede2cac52b3011b58cfd58c84f9         1
#
# [2895 rows x 3 columns]

# %%
prueba4= items3.groupby(["customer_state", "product_category_name"])["order_id"].count().sort_values(ascending=False).reset_index().head(5)
prueba4
# Out:
#   customer_state  product_category_name  order_id
# 0             SP        cama_mesa_banho       568
# 1             SP           beleza_saude       544
# 2             SP     relogios_presentes       437
# 3             SP       moveis_decoracao       417
# 4             SP  utilidades_domesticas       387

# %%
items5 = items4[items4["customer_state"].isin(["SP","RJ", "MG","RS", "PR", "BA", "SC"])]
items5

#data313_ordenes_items_productos_Gen =  data313_ordenes_items_productos_sin_SP[data313_ordenes_items_productos_sin_SP["customer_state"].isin(["RJ", "MG","RS", "PR", "BA", "SC"])]
#data313_ordenes_items_productos_Gen
# Out:
#                                order_id  order_item_id  \
# 0      000576fe39319847cbb9d288c5617fa6              1
# 1      0009c9a17f916a706d71784483a5d643              1
# 2      000aed2e25dbad2f9ddb70584c5a2ded              1
# 5      0029c5db35ef291ce99d1262012e7daa              1
# 6      002c9def9c9b951b1bec6d50753c9891              1
# ...                                 ...            ...
# 12838  ffc49b9c9d666410e9ecdb0a3efadb9c              1
# 12839  ffc97f5975c4aa1b3c9754d83050c73d              1
# 12840  ffea20c7630343a6cd9e09858c1295cd              1
# 12841  ffebd80e3291e811c308365936897efd              1
# 12843  fffcd46ef2263f404302a634eb57f7eb              1
#
#                              product_id                         seller_id  \
# 0      557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 1      3f27ac8e699df3d300ec4a5d8c5cf0b2  fcb5ace8bcc92f75707dc0f01a27d269
# 2      4fa33915031a8cde03dd0d3e8fb27f01  fe2032dab1a61af8794248c8196565c9
# ...

# %%
prueba5= items5.groupby(["customer_state", "product_category_name"])["order_id"].count().sort_values(ascending=False).reset_index()
prueba5
# Out:
#     customer_state           product_category_name  order_id
# 0               SP                 cama_mesa_banho       568
# 1               SP                    beleza_saude       544
# 2               SP              relogios_presentes       437
# 3               SP                moveis_decoracao       417
# 4               SP           utilidades_domesticas       387
# ..             ...                             ...       ...
# 340             SP  fashion_underwear_e_moda_praia         1
# 341             SP                 fraldas_higiene         1
# 342             SP                          flores         1
# 343             BA                           audio         1
# 344             BA                artigos_de_natal         1
#
# [345 rows x 3 columns]

# %%
top_categorias5 = (prueba5.sort_values(['customer_state', "order_id"], ascending=[True, False]).groupby('customer_state').head(5))
top_categorias5
# Out:
#    customer_state   product_category_name  order_id
# 39             BA            beleza_saude        63
# 43             BA      relogios_presentes        57
# 67             BA        moveis_decoracao        34
# 69             BA         cama_mesa_banho        33
# 85             BA   utilidades_domesticas        27
# 13             MG            beleza_saude       148
# 14             MG         cama_mesa_banho       138
# 17             MG   utilidades_domesticas       135
# 18             MG      relogios_presentes       133
# 26             MG        moveis_decoracao       107
# 32             PR      relogios_presentes        74
# 34             PR        moveis_decoracao        71
# 44             PR            beleza_saude        56
# 47             PR         cama_mesa_banho        51
# 48             PR   utilidades_domesticas        51
# 8              RJ      relogios_presentes       173
# 12             RJ            beleza_saude       151
# ...

# %%
ultimas_categorias5 = (prueba5.sort_values(['customer_state', "order_id"], ascending=[True, False]).groupby('customer_state').tail(5))
ultimas_categorias5
# Out:
#     customer_state                          product_category_name  order_id
# 309             BA                                 consoles_games         1
# 335             BA                               fashion_calcados         1
# 338             BA                                  moveis_quarto         1
# 343             BA                                          audio         1
# 344             BA                               artigos_de_natal         1
# 332             MG                  construcao_ferramentas_jardim         1
# 333             MG  portateis_cozinha_e_preparadores_de_alimentos         1
# 334             MG                  industria_comercio_e_negocios         1
# 336             MG                               artigos_de_natal         1
# 339             MG                                      cine_foto         1
# 313             PR                                      cine_foto         1
# ...

# %%
grouped = items5.groupby(["customer_state", "Dia_Sem"])["Dia_Sem"].count()

# %%
grouped_df = grouped.reset_index(name='count')

# %%
min_days = grouped_df.loc[grouped_df.groupby("customer_state")["count"].idxmin()]
min_days
# Out:
#    customer_state   Dia_Sem  count
# 2              BA  Saturday     49
# 9              MG  Saturday    146
# 16             PR  Saturday     57
# 24             RJ    Sunday    185
# 30             RS  Saturday     50
# 37             SC  Saturday     55
# 44             SP  Saturday    499

# %%
prueba6= items5.groupby(["customer_state", "product_id", "product_category_name"])["order_id"].count().reset_index()
prueba6
# Out:
#      customer_state                        product_id  \
# 0                BA  01cb96c64e8e35f29826a58963f6ecc5
# 1                BA  01cf56cd6138b926a4802d16fc304149
# 2                BA  02ad78835ec3f72e750d1dfa6a7e11b3
# 3                BA  02b750ee6f6f12a23c311b775ee4427a
# 4                BA  03826ede2cac52b3011b58cfd58c84f9
# ...             ...                               ...
# 6514             SP  ffbfe460c6f140cdbe4f494be6dd43be
# 6515             SP  ffc9caf33e2d1e9f44e3e06da19085f7
# 6516             SP  ffd2365fb8224dc66883df9351d65deb
# 6517             SP  ffe013e1b4603e3b0b02fbb159d5b400
# 6518             SP  fff1059cd247279f3726b7696c66e44e
#
#                   product_category_name  order_id
# 0     construcao_ferramentas_iluminacao         1
# 1                           eletronicos         1
# 2                      moveis_decoracao         2
# 3                                 bebes         1
# 4                 utilidades_domesticas         1
# ...

# %%
top_productos6 = (prueba6.sort_values(['customer_state', "order_id"], ascending=[True, False]).groupby('customer_state').head(5))
top_productos6
# Out:
#      customer_state                        product_id  \
# 303              BA  e7cc48a9daff5436f63d3aad9426f28b
# 91               BA  3dd2a17168ec895c781a9191c1e95ad7
# 191              BA  8ed094bfe076c568f6bb10feada3f75d
# 246              BA  bb50f2e236e5eea0100680137654686c
# 133              BA  5f00c50de3d989194f0439e343480372
# 579              MG  3dd2a17168ec895c781a9191c1e95ad7
# 755              MG  6f3b5b605d91b7439c5e3f5a8dffeea7
# 655              MG  52c80cedd4e90108bf4fa6a206ef6b03
# 911              MG  97f1396a5a1f7c07ba51784efdec44b8
# 1258             MG  f8b624d4e475bb8d1bddf1b65c6a64f6
# 1580             PR  8ed094bfe076c568f6bb10feada3f75d
# 1701             PR  d285360f29ac7fd97640bf0baef03de0
# 1463             PR  4deb009c36a910076a023947a7929201
# 1636             PR  b114bf337c0626166abe574eee9e3f32
# 1321             PR  0bbdc963004d9b2fd3427ee3c5ae3608
# 2085             RJ  52c80cedd4e90108bf4fa6a206ef6b03
# ...

# %%
ultimos_productos6 = (prueba6.sort_values(['customer_state', "order_id"], ascending=[True, False]).groupby('customer_state').tail(5))
ultimos_productos6
# Out:
#      customer_state                        product_id  \
# 347              BA  fe75529a267b76ac6e96f0c322a899a4
# 348              BA  fe9dfbe7f974621789683b7b78be2a16
# 349              BA  ff3ec972ebd16eb98d55e8ea2fa255ee
# 350              BA  ff5d87897ed26d564711df324b98ebee
# 351              BA  ffc9caf33e2d1e9f44e3e06da19085f7
# 1290             MG  fdc1340be043a0e6807741d687fc1cd4
# 1291             MG  fdf37ff6a4ff39ac973343a01c1f91ef
# 1292             MG  fe077ec80df6b4ee60bb4498d5ab1962
# 1293             MG  feeed1b9f26cce6eb3cb81af65eddd9e
# 1295             MG  ffc9caf33e2d1e9f44e3e06da19085f7
# 1774             PR  fe077ec80df6b4ee60bb4498d5ab1962
# 1776             PR  fea2f92877b647dc07ea8e3f4aa2cf3f
# 1777             PR  feb18700015c20ef4ca5098a6288f6f7
# 1778             PR  ff274e9a1f40c1c9bc8a2069af3a0084
# 1780             PR  ffd2365fb8224dc66883df9351d65deb
# 2783             RJ  fe8b0ea4a95d3a6488d8e23b41720e46
# ...

# %%
prueba5[prueba5["order_id"]==1]
# Out:
#     customer_state                          product_category_name  order_id
# 295             BA                                  casa_conforto         1
# 296             BA                                casa_construcao         1
# 297             RS                                       pc_gamer         1
# 298             RS                                   market_place         1
# 299             RS                         livros_interesse_geral         1
# 300             SC                               fashion_calcados         1
# 301             SC                                        bebidas         1
# 302             SC                                  casa_conforto         1
# 303             SC                             artes_e_artesanato         1
# 304             SC                                          audio         1
# 305             SP  portateis_cozinha_e_preparadores_de_alimentos         1
# ...

# %%
items5
# Out:
#                                order_id  order_item_id  \
# 0      000576fe39319847cbb9d288c5617fa6              1
# 1      0009c9a17f916a706d71784483a5d643              1
# 2      000aed2e25dbad2f9ddb70584c5a2ded              1
# 5      0029c5db35ef291ce99d1262012e7daa              1
# 6      002c9def9c9b951b1bec6d50753c9891              1
# ...                                 ...            ...
# 12838  ffc49b9c9d666410e9ecdb0a3efadb9c              1
# 12839  ffc97f5975c4aa1b3c9754d83050c73d              1
# 12840  ffea20c7630343a6cd9e09858c1295cd              1
# 12841  ffebd80e3291e811c308365936897efd              1
# 12843  fffcd46ef2263f404302a634eb57f7eb              1
#
#                              product_id                         seller_id  \
# 0      557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 1      3f27ac8e699df3d300ec4a5d8c5cf0b2  fcb5ace8bcc92f75707dc0f01a27d269
# 2      4fa33915031a8cde03dd0d3e8fb27f01  fe2032dab1a61af8794248c8196565c9
# ...

# %%
items5["state_category"] = items5["customer_state"] + items5["product_category_name"]
items5
# Out:
# /tmp/ipython-input-1025761656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items5["state_category"] = items5["customer_state"] + items5["product_category_name"]
#                                order_id  order_item_id  \
# 0      000576fe39319847cbb9d288c5617fa6              1
# 1      0009c9a17f916a706d71784483a5d643              1
# 2      000aed2e25dbad2f9ddb70584c5a2ded              1
# 5      0029c5db35ef291ce99d1262012e7daa              1
# 6      002c9def9c9b951b1bec6d50753c9891              1
# ...                                 ...            ...
# 12838  ffc49b9c9d666410e9ecdb0a3efadb9c              1
# 12839  ffc97f5975c4aa1b3c9754d83050c73d              1
# 12840  ffea20c7630343a6cd9e09858c1295cd              1
# ...

# %%
top_categorias5
# Out:
#    customer_state   product_category_name  order_id
# 39             BA            beleza_saude        63
# 43             BA      relogios_presentes        57
# 67             BA        moveis_decoracao        34
# 69             BA         cama_mesa_banho        33
# 85             BA   utilidades_domesticas        27
# 13             MG            beleza_saude       148
# 14             MG         cama_mesa_banho       138
# 17             MG   utilidades_domesticas       135
# 18             MG      relogios_presentes       133
# 26             MG        moveis_decoracao       107
# 32             PR      relogios_presentes        74
# 34             PR        moveis_decoracao        71
# 44             PR            beleza_saude        56
# 47             PR         cama_mesa_banho        51
# 48             PR   utilidades_domesticas        51
# 8              RJ      relogios_presentes       173
# 12             RJ            beleza_saude       151
# ...

# %%
top_categorias5["state_category"] = top_categorias5["customer_state"] + top_categorias5["product_category_name"]
top_categorias5
# Out:
#    customer_state   product_category_name  order_id            state_category
# 39             BA            beleza_saude        63            BAbeleza_saude
# 43             BA      relogios_presentes        57      BArelogios_presentes
# 67             BA        moveis_decoracao        34        BAmoveis_decoracao
# 69             BA         cama_mesa_banho        33         BAcama_mesa_banho
# 85             BA   utilidades_domesticas        27   BAutilidades_domesticas
# 13             MG            beleza_saude       148            MGbeleza_saude
# 14             MG         cama_mesa_banho       138         MGcama_mesa_banho
# 17             MG   utilidades_domesticas       135   MGutilidades_domesticas
# 18             MG      relogios_presentes       133      MGrelogios_presentes
# 26             MG        moveis_decoracao       107        MGmoveis_decoracao
# 32             PR      relogios_presentes        74      PRrelogios_presentes
# ...

# %%
items6 = items5.merge(top_categorias5, on="state_category", how="inner")
items6
# Out:
#                             order_id_x  order_item_id  \
# 0     0029c5db35ef291ce99d1262012e7daa              1
# 1     002c9def9c9b951b1bec6d50753c9891              1
# 2     002c9def9c9b951b1bec6d50753c9891              2
# 3     002f16b7bc4530031b7d90f791b12d8a              1
# 4     007bbb40c95870c0f75a7855f2636c65              1
# ...                                ...            ...
# 4773  ffb2c3a5bb149a2f860e5d057096201f              2
# 4774  ffb2c3a5bb149a2f860e5d057096201f              3
# 4775  ffb2c3a5bb149a2f860e5d057096201f              4
# 4776  ffc49b9c9d666410e9ecdb0a3efadb9c              1
# 4777  ffc97f5975c4aa1b3c9754d83050c73d              1
#
#                             product_id                         seller_id  \
# 0     7614c62b86a81021243e438cfde78ccc  900ba814c251a692506d7834c1218441
# 1     2d9ff06c8870a518f5f6909774e140fb  00720abe85ba0859807595bbf045a33b
# 2     2d9ff06c8870a518f5f6909774e140fb  00720abe85ba0859807595bbf045a33b
# ...

# %%
##items7prueba = items6[items6["customer_state_y"]=="BA"]
##items7prueba
# Out:
#                             order_id_x  order_item_id  \
# 22    01825d0debce07b6502f4aff38a00e69              1
# 35    02640665fed0e2c2cdbe0f266a2aa1f2              1
# 102   06a31d324c43e3350e4a83fb663c151a              1
# 108   06d9e69034388abf6da64378e10737b8              1
# 109   06d9e69034388abf6da64378e10737b8              2
# ...                                ...            ...
# 4737  fd3d5d5f83a8dc51d0acbca416b5e7b6              1
# 4743  fd607d0a02cb276bc764a15f80f0423f              1
# 4744  fd607d0a02cb276bc764a15f80f0423f              2
# 4748  fe008cc13679ac6992b975115fe63cb5              1
# 4767  ff543157c2f72dec558dfc734cfd46f7              1
#
#                             product_id                         seller_id  \
# 22    3d1d7aa3dfc91ac9490303d6c7342e83  4a3ca9315b744ce9f8e9374361493884
# 35    78304982b107fb026e5e9a4a1f48acae  8160255418d5aaa7dbdc9f4c64ebda44
# 102   944a8fa6055b8213f9e715720d4e2d5c  da8622b14eb17ae2831f4ac5b9dab84a
# ...

# %%
##items7prueba["product_category_name_y"].value_counts()
# Out:
# product_category_name_y
# beleza_saude             63
# relogios_presentes       57
# moveis_decoracao         34
# cama_mesa_banho          33
# utilidades_domesticas    27
# Name: count, dtype: int64

# %%
prueba7 = items6.groupby(["state_category","customer_state_y", "product_id", "product_category_name_y","price"])["order_id_y"].count().reset_index()
prueba7
# Out:
#                state_category customer_state_y  \
# 0              BAbeleza_saude               BA
# 1              BAbeleza_saude               BA
# 2              BAbeleza_saude               BA
# 3              BAbeleza_saude               BA
# 4              BAbeleza_saude               BA
# ...                       ...              ...
# 3146  SPutilidades_domesticas               SP
# 3147  SPutilidades_domesticas               SP
# 3148  SPutilidades_domesticas               SP
# 3149  SPutilidades_domesticas               SP
# 3150  SPutilidades_domesticas               SP
#
#                             product_id product_category_name_y   price  \
# 0     050d890ccc1c0874e166c9af9c6dd821            beleza_saude   85.61
# 1     06c950c36d589b39b34f5dc1d4a75e29            beleza_saude  499.65
# 2     0a783d7ce18a37749c3a059cf829564b            beleza_saude  151.00
# 3     0a783d7ce18a37749c3a059cf829564b            beleza_saude  152.00
# ...

# %%
top_productos7 = (prueba7.sort_values(['state_category', "order_id_y"], ascending=[True, False]).groupby('state_category').head(1))
top_productos7
# Out:
#                 state_category customer_state_y  \
# 32              BAbeleza_saude               BA
# 56           BAcama_mesa_banho               BA
# 86          BAmoveis_decoracao               BA
# 115       BArelogios_presentes               BA
# 174    BAutilidades_domesticas               BA
# 194             MGbeleza_saude               MG
# 331          MGcama_mesa_banho               MG
# 401         MGmoveis_decoracao               MG
# 481       MGrelogios_presentes               MG
# 620    MGutilidades_domesticas               MG
# 641             PRbeleza_saude               PR
# 688          PRcama_mesa_banho               PR
# 732         PRmoveis_decoracao               PR
# 806       PRrelogios_presentes               PR
# 839    PRutilidades_domesticas               PR
# 872             RJbeleza_saude               RJ
# 1003         RJcama_mesa_banho               RJ
# 1095        RJmoveis_decoracao               RJ
# ...

# %%
ultimos7 = (prueba7.sort_values(['state_category', "order_id_y"], ascending=[True, False]).groupby('state_category').tail(10))
ultimos7
# Out:
#                state_category customer_state_y  \
# 39             BAbeleza_saude               BA
# 40             BAbeleza_saude               BA
# 41             BAbeleza_saude               BA
# 42             BAbeleza_saude               BA
# 43             BAbeleza_saude               BA
# ...                       ...              ...
# 3142  SPutilidades_domesticas               SP
# 3145  SPutilidades_domesticas               SP
# 3147  SPutilidades_domesticas               SP
# 3148  SPutilidades_domesticas               SP
# 3150  SPutilidades_domesticas               SP
#
#                             product_id product_category_name_y   price  \
# 39    ed60a3c48bc2642660f93ddaeddd6515            beleza_saude  339.00
# 40    ef814c6dd6dc000a73c50dbaedef4002            beleza_saude  141.61
# 41    f2c6bb3c72a67ac37f14bae1faddcf40            beleza_saude  151.72
# 42    f7740e5b4337a3cc4a8a204553101a85            beleza_saude  485.90
# ...

# %%
filtro = prueba7[prueba7["order_id_y"]==1]
filtro
# Out:
#                state_category customer_state_y  \
# 0              BAbeleza_saude               BA
# 1              BAbeleza_saude               BA
# 2              BAbeleza_saude               BA
# 3              BAbeleza_saude               BA
# 4              BAbeleza_saude               BA
# ...                       ...              ...
# 3142  SPutilidades_domesticas               SP
# 3145  SPutilidades_domesticas               SP
# 3147  SPutilidades_domesticas               SP
# 3148  SPutilidades_domesticas               SP
# 3150  SPutilidades_domesticas               SP
#
#                             product_id product_category_name_y   price  \
# 0     050d890ccc1c0874e166c9af9c6dd821            beleza_saude   85.61
# 1     06c950c36d589b39b34f5dc1d4a75e29            beleza_saude  499.65
# 2     0a783d7ce18a37749c3a059cf829564b            beleza_saude  151.00
# 3     0a783d7ce18a37749c3a059cf829564b            beleza_saude  152.00
# ...

# %%
top1precio = (filtro.sort_values(['state_category', "price"], ascending=[True, False]).groupby('state_category').head(1))
top1precio
# Out:
#                 state_category customer_state_y  \
# 14              BAbeleza_saude               BA
# 65           BAcama_mesa_banho               BA
# 95          BAmoveis_decoracao               BA
# 129       BArelogios_presentes               BA
# 170    BAutilidades_domesticas               BA
# 230             MGbeleza_saude               MG
# 347          MGcama_mesa_banho               MG
# 424         MGmoveis_decoracao               MG
# 455       MGrelogios_presentes               MG
# 610    MGutilidades_domesticas               MG
# 633             PRbeleza_saude               PR
# 676          PRcama_mesa_banho               PR
# 724         PRmoveis_decoracao               PR
# 773       PRrelogios_presentes               PR
# 849    PRutilidades_domesticas               PR
# 889             RJbeleza_saude               RJ
# 997          RJcama_mesa_banho               RJ
# 1138        RJmoveis_decoracao               RJ
# ...

# %%
top_productos7
# Out:
#                 state_category customer_state_y  \
# 32              BAbeleza_saude               BA
# 56           BAcama_mesa_banho               BA
# 86          BAmoveis_decoracao               BA
# 115       BArelogios_presentes               BA
# 174    BAutilidades_domesticas               BA
# 194             MGbeleza_saude               MG
# 331          MGcama_mesa_banho               MG
# 401         MGmoveis_decoracao               MG
# 481       MGrelogios_presentes               MG
# 620    MGutilidades_domesticas               MG
# 641             PRbeleza_saude               PR
# 688          PRcama_mesa_banho               PR
# 732         PRmoveis_decoracao               PR
# 806       PRrelogios_presentes               PR
# 839    PRutilidades_domesticas               PR
# 872             RJbeleza_saude               RJ
# 1003         RJcama_mesa_banho               RJ
# 1095        RJmoveis_decoracao               RJ
# ...

# %%
base_combos = top_productos7.merge(top1precio, on="state_category", how="inner")
base_combos
# Out:
#               state_category customer_state_y_x  \
# 0             BAbeleza_saude                 BA
# 1          BAcama_mesa_banho                 BA
# 2         BAmoveis_decoracao                 BA
# 3       BArelogios_presentes                 BA
# 4    BAutilidades_domesticas                 BA
# 5             MGbeleza_saude                 MG
# 6          MGcama_mesa_banho                 MG
# 7         MGmoveis_decoracao                 MG
# 8       MGrelogios_presentes                 MG
# 9    MGutilidades_domesticas                 MG
# 10            PRbeleza_saude                 PR
# 11         PRcama_mesa_banho                 PR
# 12        PRmoveis_decoracao                 PR
# 13      PRrelogios_presentes                 PR
# 14   PRutilidades_domesticas                 PR
# 15            RJbeleza_saude                 RJ
# 16         RJcama_mesa_banho                 RJ
# 17        RJmoveis_decoracao                 RJ
# ...

# %%
base_combos = base_combos.rename(columns={"product_id_x":"producto_mas_vendido", "product_id_y":"producto_menos_vendido", "product_category_name_y_x":"categoria_x", "product_category_name_y_y":"categoria_y", "price_x":"precio_mas_vendido","price_y":"precio_menos_vendido", "order_id_y_x":"cantidad_ordenes_mas_vendida","order_id_y_y":"cantidad_ordenes_menos_vendida","customer_state_y_x":"estado_x","customer_state_y_y":"estado_y"})
base_combos
# Out:
#               state_category estado_x              producto_mas_vendido  \
# 0             BAbeleza_saude       BA  bb50f2e236e5eea0100680137654686c
# 1          BAcama_mesa_banho       BA  5f00c50de3d989194f0439e343480372
# 2         BAmoveis_decoracao       BA  952ef4ed720bf5d77f42712da90f2f49
# 3       BArelogios_presentes       BA  53b36df67ebb7c41585e8d54d6772e08
# 4    BAutilidades_domesticas       BA  ea74c867ca62f47d2c6bb8f14bdd34df
# 5             MGbeleza_saude       MG  24c66f106f642621e524291a895c9032
# 6          MGcama_mesa_banho       MG  99a4788cb24856965c36a24e339b6058
# 7         MGmoveis_decoracao       MG  7814c273ab16783d73a9863ebfa8b141
# 8       MGrelogios_presentes       MG  6f3b5b605d91b7439c5e3f5a8dffeea7
# 9    MGutilidades_domesticas       MG  f8b624d4e475bb8d1bddf1b65c6a64f6
# 10            PRbeleza_saude       PR  6cdd53843498f92890544667809f1595
# 11         PRcama_mesa_banho       PR  9e2c54c2ff2dec92562afa5284200869
# ...

# %%
base_combos
# Out:
#               state_category estado_x              producto_mas_vendido  \
# 0             BAbeleza_saude       BA  bb50f2e236e5eea0100680137654686c
# 1          BAcama_mesa_banho       BA  5f00c50de3d989194f0439e343480372
# 2         BAmoveis_decoracao       BA  952ef4ed720bf5d77f42712da90f2f49
# 3       BArelogios_presentes       BA  53b36df67ebb7c41585e8d54d6772e08
# 4    BAutilidades_domesticas       BA  ea74c867ca62f47d2c6bb8f14bdd34df
# 5             MGbeleza_saude       MG  24c66f106f642621e524291a895c9032
# 6          MGcama_mesa_banho       MG  99a4788cb24856965c36a24e339b6058
# 7         MGmoveis_decoracao       MG  7814c273ab16783d73a9863ebfa8b141
# 8       MGrelogios_presentes       MG  6f3b5b605d91b7439c5e3f5a8dffeea7
# 9    MGutilidades_domesticas       MG  f8b624d4e475bb8d1bddf1b65c6a64f6
# 10            PRbeleza_saude       PR  6cdd53843498f92890544667809f1595
# 11         PRcama_mesa_banho       PR  9e2c54c2ff2dec92562afa5284200869
# ...

# %%
base_combos["precio_total"] = base_combos["precio_mas_vendido"] + base_combos["precio_menos_vendido"]
base_combos
# Out:
#               state_category estado_x              producto_mas_vendido  \
# 0             BAbeleza_saude       BA  bb50f2e236e5eea0100680137654686c
# 1          BAcama_mesa_banho       BA  5f00c50de3d989194f0439e343480372
# 2         BAmoveis_decoracao       BA  952ef4ed720bf5d77f42712da90f2f49
# 3       BArelogios_presentes       BA  53b36df67ebb7c41585e8d54d6772e08
# 4    BAutilidades_domesticas       BA  ea74c867ca62f47d2c6bb8f14bdd34df
# 5             MGbeleza_saude       MG  24c66f106f642621e524291a895c9032
# 6          MGcama_mesa_banho       MG  99a4788cb24856965c36a24e339b6058
# 7         MGmoveis_decoracao       MG  7814c273ab16783d73a9863ebfa8b141
# 8       MGrelogios_presentes       MG  6f3b5b605d91b7439c5e3f5a8dffeea7
# 9    MGutilidades_domesticas       MG  f8b624d4e475bb8d1bddf1b65c6a64f6
# 10            PRbeleza_saude       PR  6cdd53843498f92890544667809f1595
# 11         PRcama_mesa_banho       PR  9e2c54c2ff2dec92562afa5284200869
# ...

# %%
base_combos["precio_combo"] = base_combos["precio_total"]*0.8
base_combos
# Out:
#               state_category estado_x              producto_mas_vendido  \
# 0             BAbeleza_saude       BA  bb50f2e236e5eea0100680137654686c
# 1          BAcama_mesa_banho       BA  5f00c50de3d989194f0439e343480372
# 2         BAmoveis_decoracao       BA  952ef4ed720bf5d77f42712da90f2f49
# 3       BArelogios_presentes       BA  53b36df67ebb7c41585e8d54d6772e08
# 4    BAutilidades_domesticas       BA  ea74c867ca62f47d2c6bb8f14bdd34df
# 5             MGbeleza_saude       MG  24c66f106f642621e524291a895c9032
# 6          MGcama_mesa_banho       MG  99a4788cb24856965c36a24e339b6058
# 7         MGmoveis_decoracao       MG  7814c273ab16783d73a9863ebfa8b141
# 8       MGrelogios_presentes       MG  6f3b5b605d91b7439c5e3f5a8dffeea7
# 9    MGutilidades_domesticas       MG  f8b624d4e475bb8d1bddf1b65c6a64f6
# 10            PRbeleza_saude       PR  6cdd53843498f92890544667809f1595
# 11         PRcama_mesa_banho       PR  9e2c54c2ff2dec92562afa5284200869
# ...
